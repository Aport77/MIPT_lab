# %% [markdown]
# ## Lab 2
# ### Part 2: Dealing with overfitting

# %% [markdown]
# Today we work with [Fashion-MNIST dataset](https://github.com/zalandoresearch/fashion-mnist) (*hint: it is available in `torchvision`*).
#
# Your goal for today:
# 1. Train a FC (fully-connected) network that achieves >= 0.885 test accuracy.
# 2. Cause considerable overfitting by modifying the network (e.g. increasing the number of network parameters and/or layers) and demonstrate in in the appropriate way (e.g. plot loss and accurasy on train and validation set w.r.t. network complexity).
# 3. Try to deal with overfitting (at least partially) by using regularization techniques (Dropout/Batchnorm/...) and demonstrate the results.
#
# __Please, write a small report describing your ideas, tries and achieved results in the end of this file.__
#
# *Note*: Tasks 2 and 3 are interrelated, in task 3 your goal is to make the network from task 2 less prone to overfitting. Task 1 is independent from 2 and 3.
#
# *Note 2*: We recomment to use Google Colab or other machine with GPU acceleration.

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torchsummary
from IPython.display import clear_output
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import os


device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
import random

# Фиксируем seed
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
# Technical function
def mkdir(path):
    if not os.path.exists(root_path):
        os.mkdir(root_path)
        print('Directory', path, 'is created!')
    else:
        print('Directory', path, 'already exists!')

root_path = 'fmnist'
mkdir(root_path)
# Out:
# Directory fmnist is created!

# %%
download = True
train_transform = transforms.ToTensor()
test_transform = transforms.ToTensor()
transforms.Compose((transforms.ToTensor()))


fmnist_dataset_train = torchvision.datasets.FashionMNIST(root_path,
                                                        train=True,
                                                        transform=train_transform,
                                                        target_transform=None,
                                                        download=download)
fmnist_dataset_test = torchvision.datasets.FashionMNIST(root_path,
                                                       train=False,
                                                       transform=test_transform,
                                                       target_transform=None,
                                                       download=download)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to fmnist/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 13.4MB/s]
# Extracting fmnist/FashionMNIST/raw/train-images-idx3-ubyte.gz to fmnist/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to fmnist/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 200kB/s]
# Extracting fmnist/FashionMNIST/raw/train-labels-idx1-ubyte.gz to fmnist/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to fmnist/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.73MB/s]
# Extracting fmnist/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to fmnist/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to fmnist/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 6.26MB/s]
# Extracting fmnist/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to fmnist/FashionMNIST/raw

# %%
train_loader = torch.utils.data.DataLoader(fmnist_dataset_train,
                                           batch_size=128,
                                           shuffle=True,
                                           num_workers=2)
test_loader = torch.utils.data.DataLoader(fmnist_dataset_test,
                                          batch_size=256,
                                          shuffle=False,
                                          num_workers=2)

# %%
len(fmnist_dataset_test)
# Out:
# 10000

# %%
for img, label in train_loader:
    print(img.shape)
#     print(img)
    print(label.shape)
    print(label.size(0))
    break
# Out:
# torch.Size([128, 1, 28, 28])
# torch.Size([128])
# 128

# %% [markdown]
# ### Task 1
# Train a network that achieves $\geq 0.885$ test accuracy. It's fine to use only Linear (`nn.Linear`) layers and activations/dropout/batchnorm. Convolutional layers might be a great use, but we will meet them a bit later.

# %%
class TinyNeuralNetwork(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),                            # This layer converts image into a vector to use Linear layers afterwards
            # Your network structure comes here
            nn.Linear(input_shape, 512),             # Первый скрытый слой с 512 нейронами
            nn.BatchNorm1d(512),                     # Batch Normalization
            nn.ReLU(),                               # Активация ReLU
            nn.Dropout(0.3),                         # Dropout для регуляризации
            nn.Linear(512, 256),                     # Второй скрытый слой с 256 нейронами
            nn.BatchNorm1d(256),                     # Batch Normalization
            nn.ReLU(),                               # Активация ReLU
            nn.Dropout(0.3),                         # Dropout
            nn.Linear(256, num_classes)              # Выходной слой с 10 нейронами
        )

    def forward(self, inp):
        out = self.model(inp)
        return out

# %%
torchsummary.summary(TinyNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                  [-1, 512]         401,920
#        BatchNorm1d-3                  [-1, 512]           1,024
#               ReLU-4                  [-1, 512]               0
#            Dropout-5                  [-1, 512]               0
#             Linear-6                  [-1, 256]         131,328
#        BatchNorm1d-7                  [-1, 256]             512
#               ReLU-8                  [-1, 256]               0
#            Dropout-9                  [-1, 256]               0
#            Linear-10                   [-1, 10]           2,570
# ================================================================
# Total params: 537,354
# Trainable params: 537,354
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.03
# Params size (MB): 2.05
# Estimated Total Size (MB): 2.08
# ----------------------------------------------------------------

# %% [markdown]
# Your experiments come here:

# %%
import torch.optim as optim

# Инициализация модели, функции потерь и оптимизатора
model = TinyNeuralNetwork().to(device)
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Цикл обучения
num_epochs = 30
train_losses = []
test_accuracies = []

for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    correct = 0
    total = 0

    # Обучение на тренировочном наборе
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        predictions = model(x)
        loss = loss_func(predictions, y)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(predictions.data, 1)
        total += y.size(0)
        correct += (predicted == y).sum().item()

    train_losses.append(train_loss / len(train_loader))

    # Оценка на тестовом наборе
    model.eval()
    correct_test = 0
    total_test = 0

    with torch.no_grad():
        for x_test, y_test in test_loader:
            x_test, y_test = x_test.to(device), y_test.to(device)
            predictions = model(x_test)
            _, predicted_test = torch.max(predictions.data, 1)
            total_test += y_test.size(0)
            correct_test += (predicted_test == y_test).sum().item()

    test_accuracy = correct_test / total_test
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {train_loss / len(train_loader):.4f}, Test Accuracy: {test_accuracy:.4f}")

# Финальная оценка точности
print(f"Финальная точность теста: {test_accuracies[-1]:.4f}")
# Out:
# Epoch 1/30, Loss: 0.4821, Test Accuracy: 0.8487
# Epoch 2/30, Loss: 0.3719, Test Accuracy: 0.8658
# Epoch 3/30, Loss: 0.3384, Test Accuracy: 0.8697
# Epoch 4/30, Loss: 0.3170, Test Accuracy: 0.8765
# Epoch 5/30, Loss: 0.2992, Test Accuracy: 0.8802
# Epoch 6/30, Loss: 0.2865, Test Accuracy: 0.8751
# Epoch 7/30, Loss: 0.2688, Test Accuracy: 0.8821
# Epoch 8/30, Loss: 0.2629, Test Accuracy: 0.8866
# Epoch 9/30, Loss: 0.2512, Test Accuracy: 0.8852
# Epoch 10/30, Loss: 0.2463, Test Accuracy: 0.8907
# Epoch 11/30, Loss: 0.2356, Test Accuracy: 0.8897
# Epoch 12/30, Loss: 0.2286, Test Accuracy: 0.8897
# Epoch 13/30, Loss: 0.2220, Test Accuracy: 0.8979
# Epoch 14/30, Loss: 0.2139, Test Accuracy: 0.8948
# Epoch 15/30, Loss: 0.2079, Test Accuracy: 0.8970
# Epoch 16/30, Loss: 0.2001, Test Accuracy: 0.8980
# Epoch 17/30, Loss: 0.1930, Test Accuracy: 0.8939
# Epoch 18/30, Loss: 0.1922, Test Accuracy: 0.8921
# Epoch 19/30, Loss: 0.1856, Test Accuracy: 0.8998
# Epoch 20/30, Loss: 0.1792, Test Accuracy: 0.8915
# Epoch 21/30, Loss: 0.1747, Test Accuracy: 0.9017
# Epoch 22/30, Loss: 0.1708, Test Accuracy: 0.8992
# Epoch 23/30, Loss: 0.1669, Test Accuracy: 0.8927
# Epoch 24/30, Loss: 0.1609, Test Accuracy: 0.8973
# Epoch 25/30, Loss: 0.1586, Test Accuracy: 0.9006
# Epoch 26/30, Loss: 0.1549, Test Accuracy: 0.9011
# Epoch 27/30, Loss: 0.1533, Test Accuracy: 0.9008
# Epoch 28/30, Loss: 0.1479, Test Accuracy: 0.8941
# Epoch 29/30, Loss: 0.1431, Test Accuracy: 0.8972
# Epoch 30/30, Loss: 0.1401, Test Accuracy: 0.8966
# Финальная точность теста: 0.8966

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# График функции потерь
ax1.plot(range(1, num_epochs + 1), train_losses)
ax1.set_xlabel("Эпохи", fontsize=12)
ax1.set_ylabel("Функция потерь", fontsize=12)
ax1.set_title("График функции потерь", fontsize=14)

# График точности
ax2.plot(range(1, num_epochs + 1), test_accuracies, label="График точности")
ax2.axhline(0.885, color='r', linestyle='--', label="Целевая точность (0.885)")
ax2.set_xlabel("Эпохи", fontsize=12)
ax2.set_ylabel("Точность", fontsize=12)
ax2.set_title("График точности", fontsize=14)
ax2.legend(loc='lower right', fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 2: Overfit it.
# Build a network that will overfit to this dataset. Demonstrate the overfitting in the appropriate way (e.g. plot loss and accurasy on train and test set w.r.t. network complexity).
#
# *Note:* you also might decrease the size of `train` dataset to enforce the overfitting and speed up the computations.

# %%
class OverfittingNeuralNetwork(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(), # This layer converts image into a vector to use Linear layers afterwards
            # Your network structure comes here
            nn.Linear(input_shape, 2048),
            nn.ReLU(),
            nn.Linear(2048, 2048),  # Еще один слой с большим количеством нейронов
            nn.ReLU(),
            nn.Linear(2048, 2048),  # еще слой с большим количеством нейронов
            nn.ReLU(),
            nn.Linear(2048, 2048),  # еще слой с большим количеством нейронов
            nn.ReLU(),
            nn.Linear(2048, 2048),  # и еще слой с большим количеством нейронов
            nn.ReLU(),
            nn.Linear(2048, num_classes)  # Выходной слой
        )

    def forward(self, inp):
        out = self.model(inp)
        return out

# %%
torchsummary.summary(OverfittingNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                 [-1, 2048]       1,607,680
#               ReLU-3                 [-1, 2048]               0
#             Linear-4                 [-1, 2048]       4,196,352
#               ReLU-5                 [-1, 2048]               0
#             Linear-6                 [-1, 2048]       4,196,352
#               ReLU-7                 [-1, 2048]               0
#             Linear-8                 [-1, 2048]       4,196,352
#               ReLU-9                 [-1, 2048]               0
#            Linear-10                 [-1, 2048]       4,196,352
#              ReLU-11                 [-1, 2048]               0
#            Linear-12                   [-1, 10]          20,490
# ================================================================
# Total params: 18,413,578
# Trainable params: 18,413,578
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.16
# Params size (MB): 70.24
# Estimated Total Size (MB): 70.41
# ----------------------------------------------------------------

# %%
model = OverfittingNeuralNetwork().to(device)
opt = torch.optim.Adam(model.parameters(), lr=0.001) # YOUR CODE HERE
loss_func = nn.CrossEntropyLoss() # YOUR CODE HERE

# Your experiments, come here

# %%
# Уменьшаем размер обучающего набора данных
small_train_set = torch.utils.data.Subset(fmnist_dataset_train, range(1000))
small_train_loader = torch.utils.data.DataLoader(small_train_set, batch_size=128, shuffle=True, num_workers=2)

# %%
# Функция для обучения модели
def train_model(model, train_loader, test_loader, loss_func, opt, num_epochs):
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    for epoch in range(num_epochs):
        # Обучение
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            opt.zero_grad()
            predictions = model(x)
            loss = loss_func(predictions, y)
            loss.backward()
            opt.step()
            running_loss += loss.item()
            _, predicted = torch.max(predictions, 1)
            total_train += y.size(0)
            correct_train += (predicted == y).sum().item()

        train_losses.append(running_loss / len(train_loader))
        train_accuracies.append(correct_train / total_train)

        # Тестирование
        model.eval()
        test_loss = 0.0
        correct_test = 0
        total_test = 0
        with torch.no_grad():
            for x, y in test_loader:
                x, y = x.to(device), y.to(device)
                predictions = model(x)
                loss = loss_func(predictions, y)
                test_loss += loss.item()
                _, predicted = torch.max(predictions, 1)
                total_test += y.size(0)
                correct_test += (predicted == y).sum().item()

        test_losses.append(test_loss / len(test_loader))
        test_accuracies.append(correct_test / total_test)

        # Красивый вывод результатов
        print(f"Epoch {epoch + 1}/{num_epochs} - "
              f"Train Loss: {train_losses[-1]:.4f}, Test Loss: {test_losses[-1]:.4f}, "
              f"Train Accuracy: {train_accuracies[-1]:.4f}, Test Accuracy: {test_accuracies[-1]:.4f}")

    return train_losses, test_losses, train_accuracies, test_accuracies

# %%
def plot_metrics(num_epochs, train_losses, test_losses, train_accuracies, test_accuracies):
    # График потерь и точности
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))  # 1 строка, 2 столбца

    # График функции потерь
    ax1.plot(range(1, num_epochs + 1), train_losses, label="на обучающих данных")
    ax1.plot(range(1, num_epochs + 1), test_losses, label="на тестирующих данных")
    ax1.set_xlabel("Эпохи", fontsize=12)
    ax1.set_ylabel("Потери", fontsize=12)
    ax1.set_title("Функция потерь при обучении и тестировании", fontsize=14)
    ax1.legend(loc='upper right', fontsize=12)
    ax1.grid(True)
    #ax1.set_ylim(0, 2.5)
    # График точности
    ax2.plot(range(1, num_epochs + 1), train_accuracies, label="на обучающих данных")
    ax2.plot(range(1, num_epochs + 1), test_accuracies, label="на тестирующих данных")
    ax2.set_xlabel("Эпохи", fontsize=12)
    ax2.set_ylabel("Точность", fontsize=12)
    ax2.set_title("Точность при обучении и тестировании", fontsize=14)
    ax2.legend(loc='lower right', fontsize=12)
    ax2.grid(True)
    #ax2.set_ylim(0, 1.0)
    plt.tight_layout()
    plt.show()

# %%
# Обучение модели на меньшем наборе данных
train_losses, test_losses, train_accuracies, test_accuracies = train_model(model, small_train_loader, test_loader, loss_func, opt, num_epochs=50)
# Out:
# Epoch 1/50 - Train Loss: 2.1083, Test Loss: 1.6748, Train Accuracy: 0.2450, Test Accuracy: 0.3453
# Epoch 2/50 - Train Loss: 1.4738, Test Loss: 1.1600, Train Accuracy: 0.3990, Test Accuracy: 0.5211
# Epoch 3/50 - Train Loss: 1.1026, Test Loss: 1.0203, Train Accuracy: 0.5750, Test Accuracy: 0.5753
# Epoch 4/50 - Train Loss: 0.9224, Test Loss: 0.9203, Train Accuracy: 0.6020, Test Accuracy: 0.6332
# Epoch 5/50 - Train Loss: 0.7850, Test Loss: 0.9194, Train Accuracy: 0.6750, Test Accuracy: 0.6217
# Epoch 6/50 - Train Loss: 0.7307, Test Loss: 0.9158, Train Accuracy: 0.6890, Test Accuracy: 0.6426
# Epoch 7/50 - Train Loss: 0.6058, Test Loss: 0.7473, Train Accuracy: 0.7390, Test Accuracy: 0.7083
# Epoch 8/50 - Train Loss: 0.5349, Test Loss: 0.7864, Train Accuracy: 0.7620, Test Accuracy: 0.7033
# Epoch 9/50 - Train Loss: 0.4725, Test Loss: 1.1407, Train Accuracy: 0.8080, Test Accuracy: 0.6980
# Epoch 10/50 - Train Loss: 0.4937, Test Loss: 0.7798, Train Accuracy: 0.7890, Test Accuracy: 0.7107
# Epoch 11/50 - Train Loss: 0.5107, Test Loss: 0.8266, Train Accuracy: 0.8070, Test Accuracy: 0.7176
# Epoch 12/50 - Train Loss: 0.4622, Test Loss: 1.1018, Train Accuracy: 0.8110, Test Accuracy: 0.6478
# Epoch 13/50 - Train Loss: 0.5603, Test Loss: 0.7931, Train Accuracy: 0.7850, Test Accuracy: 0.7113
# Epoch 14/50 - Train Loss: 0.4938, Test Loss: 0.8399, Train Accuracy: 0.8070, Test Accuracy: 0.7418
# Epoch 15/50 - Train Loss: 0.4749, Test Loss: 0.8657, Train Accuracy: 0.8050, Test Accuracy: 0.7199
# Epoch 16/50 - Train Loss: 0.4131, Test Loss: 0.8593, Train Accuracy: 0.8300, Test Accuracy: 0.7520
# Epoch 17/50 - Train Loss: 0.3385, Test Loss: 0.8355, Train Accuracy: 0.8550, Test Accuracy: 0.7458
# Epoch 18/50 - Train Loss: 0.3564, Test Loss: 0.8744, Train Accuracy: 0.8530, Test Accuracy: 0.7619
# Epoch 19/50 - Train Loss: 0.3328, Test Loss: 0.7865, Train Accuracy: 0.8630, Test Accuracy: 0.7753
# Epoch 20/50 - Train Loss: 0.3037, Test Loss: 0.9766, Train Accuracy: 0.8720, Test Accuracy: 0.7480
# Epoch 21/50 - Train Loss: 0.2831, Test Loss: 0.9622, Train Accuracy: 0.8940, Test Accuracy: 0.7616
# Epoch 22/50 - Train Loss: 0.2883, Test Loss: 1.1659, Train Accuracy: 0.8900, Test Accuracy: 0.7462
# Epoch 23/50 - Train Loss: 0.3536, Test Loss: 0.7736, Train Accuracy: 0.8680, Test Accuracy: 0.7660
# Epoch 24/50 - Train Loss: 0.3246, Test Loss: 0.9169, Train Accuracy: 0.8770, Test Accuracy: 0.7373
# Epoch 25/50 - Train Loss: 0.3060, Test Loss: 0.7592, Train Accuracy: 0.8870, Test Accuracy: 0.7755
# Epoch 26/50 - Train Loss: 0.2436, Test Loss: 0.9818, Train Accuracy: 0.9070, Test Accuracy: 0.7649
# Epoch 27/50 - Train Loss: 0.2273, Test Loss: 0.9228, Train Accuracy: 0.9090, Test Accuracy: 0.7689
# Epoch 28/50 - Train Loss: 0.1949, Test Loss: 0.9282, Train Accuracy: 0.9290, Test Accuracy: 0.7846
# Epoch 29/50 - Train Loss: 0.1906, Test Loss: 1.1382, Train Accuracy: 0.9290, Test Accuracy: 0.7516
# Epoch 30/50 - Train Loss: 0.3101, Test Loss: 0.8801, Train Accuracy: 0.9000, Test Accuracy: 0.7583
# Epoch 31/50 - Train Loss: 0.2153, Test Loss: 0.9480, Train Accuracy: 0.9180, Test Accuracy: 0.7703
# Epoch 32/50 - Train Loss: 0.2848, Test Loss: 0.9858, Train Accuracy: 0.8840, Test Accuracy: 0.7350
# Epoch 33/50 - Train Loss: 0.2457, Test Loss: 1.0089, Train Accuracy: 0.8980, Test Accuracy: 0.7701
# Epoch 34/50 - Train Loss: 0.2457, Test Loss: 1.1291, Train Accuracy: 0.8930, Test Accuracy: 0.7547
# Epoch 35/50 - Train Loss: 0.1959, Test Loss: 0.9784, Train Accuracy: 0.9200, Test Accuracy: 0.7697
# Epoch 36/50 - Train Loss: 0.2186, Test Loss: 0.9687, Train Accuracy: 0.9190, Test Accuracy: 0.7803
# Epoch 37/50 - Train Loss: 0.1775, Test Loss: 1.1828, Train Accuracy: 0.9300, Test Accuracy: 0.7832
# Epoch 38/50 - Train Loss: 0.1810, Test Loss: 1.2424, Train Accuracy: 0.9340, Test Accuracy: 0.7651
# Epoch 39/50 - Train Loss: 0.2222, Test Loss: 1.0075, Train Accuracy: 0.9320, Test Accuracy: 0.7822
# Epoch 40/50 - Train Loss: 0.1568, Test Loss: 1.0567, Train Accuracy: 0.9560, Test Accuracy: 0.7963
# Epoch 41/50 - Train Loss: 0.1281, Test Loss: 1.2620, Train Accuracy: 0.9530, Test Accuracy: 0.7635
# Epoch 42/50 - Train Loss: 0.1404, Test Loss: 1.1634, Train Accuracy: 0.9440, Test Accuracy: 0.7720
# Epoch 43/50 - Train Loss: 0.1530, Test Loss: 1.2045, Train Accuracy: 0.9600, Test Accuracy: 0.7885
# Epoch 44/50 - Train Loss: 0.0854, Test Loss: 1.1573, Train Accuracy: 0.9750, Test Accuracy: 0.8001
# Epoch 45/50 - Train Loss: 0.1036, Test Loss: 1.2887, Train Accuracy: 0.9690, Test Accuracy: 0.7966
# Epoch 46/50 - Train Loss: 0.1381, Test Loss: 1.2994, Train Accuracy: 0.9580, Test Accuracy: 0.7677
# Epoch 47/50 - Train Loss: 0.1345, Test Loss: 1.2444, Train Accuracy: 0.9560, Test Accuracy: 0.7819
# Epoch 48/50 - Train Loss: 0.1472, Test Loss: 1.1147, Train Accuracy: 0.9460, Test Accuracy: 0.7882
# Epoch 49/50 - Train Loss: 0.1545, Test Loss: 1.2143, Train Accuracy: 0.9440, Test Accuracy: 0.7876
# Epoch 50/50 - Train Loss: 0.1605, Test Loss: 1.1632, Train Accuracy: 0.9370, Test Accuracy: 0.7775

# %%
# Построение графиков
plot_metrics(50, train_losses, test_losses, train_accuracies, test_accuracies)

# %% [markdown]
# ### Task 3: Fix it.
# Fix the overfitted network from the previous step (at least partially) by using regularization techniques (Dropout/Batchnorm/...) and demonstrate the results.

# %%
class FixedNeuralNetwork(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),  # Конвертирует изображение в вектор
            nn.Linear(input_shape, 2048),
            nn.BatchNorm1d(2048),  # BatchNorm для стабилизации обучения
            nn.ReLU(),
            nn.Dropout(0.9),  # Dropout для уменьшения переобучения
            nn.Linear(2048, 2048),
            nn.BatchNorm1d(2048),  # BatchNorm для следующего слоя
            nn.ReLU(),
            nn.Dropout(0.7),  # Dropout
            nn.Linear(2048, 2048),
            nn.BatchNorm1d(2048),  # BatchNorm для следующего слоя
            nn.ReLU(),
            nn.Dropout(0.7),
            nn.Linear(2048, 2048),
            nn.BatchNorm1d(2048),  # BatchNorm для следующего слоя
            nn.ReLU(),
            nn.Dropout(0.5),  # Dropout
            nn.Linear(2048, num_classes)  # Выходной слой
        )

    def forward(self, inp):
        return self.model(inp)

# %%
torchsummary.summary(FixedNeuralNetwork().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                 [-1, 2048]       1,607,680
#        BatchNorm1d-3                 [-1, 2048]           4,096
#               ReLU-4                 [-1, 2048]               0
#            Dropout-5                 [-1, 2048]               0
#             Linear-6                 [-1, 2048]       4,196,352
#        BatchNorm1d-7                 [-1, 2048]           4,096
#               ReLU-8                 [-1, 2048]               0
#            Dropout-9                 [-1, 2048]               0
#            Linear-10                 [-1, 2048]       4,196,352
#       BatchNorm1d-11                 [-1, 2048]           4,096
#              ReLU-12                 [-1, 2048]               0
#           Dropout-13                 [-1, 2048]               0
#            Linear-14                 [-1, 2048]       4,196,352
#       BatchNorm1d-15                 [-1, 2048]           4,096
#              ReLU-16                 [-1, 2048]               0
#           Dropout-17                 [-1, 2048]               0
#            Linear-18                   [-1, 10]          20,490
# ================================================================
# Total params: 14,233,610
# Trainable params: 14,233,610
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.26
# Params size (MB): 54.30
# Estimated Total Size (MB): 54.56
# ----------------------------------------------------------------

# %%
model = FixedNeuralNetwork().to(device)
opt = torch.optim.Adam(model.parameters(), lr=0.001) # YOUR CODE HERE
loss_func = nn.CrossEntropyLoss()# YOUR CODE HERE

# Your experiments, come here

# %%
train_losses, test_losses, train_accuracies, test_accuracies = train_model(model, small_train_loader, test_loader, loss_func, opt, num_epochs=50)
# Out:
# Epoch 1/50 - Train Loss: 2.3347, Test Loss: 2.0933, Train Accuracy: 0.1350, Test Accuracy: 0.1591
# Epoch 2/50 - Train Loss: 1.5789, Test Loss: 1.2608, Train Accuracy: 0.4000, Test Accuracy: 0.5390
# Epoch 3/50 - Train Loss: 1.2080, Test Loss: 0.9193, Train Accuracy: 0.5310, Test Accuracy: 0.6203
# Epoch 4/50 - Train Loss: 1.0517, Test Loss: 0.9426, Train Accuracy: 0.5850, Test Accuracy: 0.6570
# Epoch 5/50 - Train Loss: 0.9829, Test Loss: 0.7954, Train Accuracy: 0.6300, Test Accuracy: 0.7088
# Epoch 6/50 - Train Loss: 0.9462, Test Loss: 0.7465, Train Accuracy: 0.6330, Test Accuracy: 0.7285
# Epoch 7/50 - Train Loss: 0.8571, Test Loss: 0.6965, Train Accuracy: 0.6800, Test Accuracy: 0.7353
# Epoch 8/50 - Train Loss: 0.8138, Test Loss: 0.6991, Train Accuracy: 0.6850, Test Accuracy: 0.7289
# Epoch 9/50 - Train Loss: 0.8310, Test Loss: 0.6959, Train Accuracy: 0.6990, Test Accuracy: 0.7203
# Epoch 10/50 - Train Loss: 0.7377, Test Loss: 0.6745, Train Accuracy: 0.7300, Test Accuracy: 0.7490
# Epoch 11/50 - Train Loss: 0.7605, Test Loss: 0.6543, Train Accuracy: 0.7340, Test Accuracy: 0.7446
# Epoch 12/50 - Train Loss: 0.7012, Test Loss: 0.6452, Train Accuracy: 0.7440, Test Accuracy: 0.7545
# Epoch 13/50 - Train Loss: 0.6878, Test Loss: 0.6323, Train Accuracy: 0.7420, Test Accuracy: 0.7645
# Epoch 14/50 - Train Loss: 0.6746, Test Loss: 0.6316, Train Accuracy: 0.7530, Test Accuracy: 0.7538
# Epoch 15/50 - Train Loss: 0.6341, Test Loss: 0.6463, Train Accuracy: 0.7490, Test Accuracy: 0.7641
# Epoch 16/50 - Train Loss: 0.5978, Test Loss: 0.6532, Train Accuracy: 0.7790, Test Accuracy: 0.7611
# Epoch 17/50 - Train Loss: 0.6170, Test Loss: 0.6203, Train Accuracy: 0.7740, Test Accuracy: 0.7750
# Epoch 18/50 - Train Loss: 0.5761, Test Loss: 0.6217, Train Accuracy: 0.7800, Test Accuracy: 0.7667
# Epoch 19/50 - Train Loss: 0.6073, Test Loss: 0.6192, Train Accuracy: 0.7570, Test Accuracy: 0.7690
# Epoch 20/50 - Train Loss: 0.5945, Test Loss: 0.6433, Train Accuracy: 0.7860, Test Accuracy: 0.7663
# Epoch 21/50 - Train Loss: 0.5780, Test Loss: 0.6684, Train Accuracy: 0.7850, Test Accuracy: 0.7599
# Epoch 22/50 - Train Loss: 0.5570, Test Loss: 0.6283, Train Accuracy: 0.7970, Test Accuracy: 0.7827
# Epoch 23/50 - Train Loss: 0.5485, Test Loss: 0.6296, Train Accuracy: 0.7950, Test Accuracy: 0.7679
# Epoch 24/50 - Train Loss: 0.5288, Test Loss: 0.5946, Train Accuracy: 0.7930, Test Accuracy: 0.7905
# Epoch 25/50 - Train Loss: 0.5619, Test Loss: 0.6080, Train Accuracy: 0.8000, Test Accuracy: 0.7877
# Epoch 26/50 - Train Loss: 0.5121, Test Loss: 0.6212, Train Accuracy: 0.8090, Test Accuracy: 0.7846
# Epoch 27/50 - Train Loss: 0.5408, Test Loss: 0.6352, Train Accuracy: 0.7980, Test Accuracy: 0.7751
# Epoch 28/50 - Train Loss: 0.4762, Test Loss: 0.6194, Train Accuracy: 0.8240, Test Accuracy: 0.7790
# Epoch 29/50 - Train Loss: 0.5008, Test Loss: 0.6146, Train Accuracy: 0.8280, Test Accuracy: 0.7927
# Epoch 30/50 - Train Loss: 0.4505, Test Loss: 0.6630, Train Accuracy: 0.8460, Test Accuracy: 0.7595
# Epoch 31/50 - Train Loss: 0.5121, Test Loss: 0.6272, Train Accuracy: 0.8130, Test Accuracy: 0.7892
# Epoch 32/50 - Train Loss: 0.4965, Test Loss: 0.6237, Train Accuracy: 0.8140, Test Accuracy: 0.7847
# Epoch 33/50 - Train Loss: 0.4680, Test Loss: 0.6383, Train Accuracy: 0.8310, Test Accuracy: 0.7796
# Epoch 34/50 - Train Loss: 0.4535, Test Loss: 0.6191, Train Accuracy: 0.8400, Test Accuracy: 0.7868
# Epoch 35/50 - Train Loss: 0.4567, Test Loss: 0.6344, Train Accuracy: 0.8430, Test Accuracy: 0.7803
# Epoch 36/50 - Train Loss: 0.4560, Test Loss: 0.6166, Train Accuracy: 0.8330, Test Accuracy: 0.7939
# Epoch 37/50 - Train Loss: 0.4682, Test Loss: 0.6386, Train Accuracy: 0.8390, Test Accuracy: 0.7802
# Epoch 38/50 - Train Loss: 0.4313, Test Loss: 0.6217, Train Accuracy: 0.8570, Test Accuracy: 0.7906
# Epoch 39/50 - Train Loss: 0.4579, Test Loss: 0.6143, Train Accuracy: 0.8300, Test Accuracy: 0.7950
# Epoch 40/50 - Train Loss: 0.3938, Test Loss: 0.6245, Train Accuracy: 0.8620, Test Accuracy: 0.7896
# Epoch 41/50 - Train Loss: 0.4279, Test Loss: 0.6165, Train Accuracy: 0.8500, Test Accuracy: 0.7953
# Epoch 42/50 - Train Loss: 0.4225, Test Loss: 0.6205, Train Accuracy: 0.8440, Test Accuracy: 0.7975
# Epoch 43/50 - Train Loss: 0.4288, Test Loss: 0.6284, Train Accuracy: 0.8350, Test Accuracy: 0.7913
# Epoch 44/50 - Train Loss: 0.4073, Test Loss: 0.6237, Train Accuracy: 0.8510, Test Accuracy: 0.7976
# Epoch 45/50 - Train Loss: 0.3681, Test Loss: 0.6649, Train Accuracy: 0.8690, Test Accuracy: 0.7898
# Epoch 46/50 - Train Loss: 0.3924, Test Loss: 0.6489, Train Accuracy: 0.8630, Test Accuracy: 0.7952
# Epoch 47/50 - Train Loss: 0.4415, Test Loss: 0.6335, Train Accuracy: 0.8470, Test Accuracy: 0.7979
# Epoch 48/50 - Train Loss: 0.3768, Test Loss: 0.6303, Train Accuracy: 0.8640, Test Accuracy: 0.7923
# Epoch 49/50 - Train Loss: 0.3869, Test Loss: 0.6238, Train Accuracy: 0.8760, Test Accuracy: 0.8017
# Epoch 50/50 - Train Loss: 0.3851, Test Loss: 0.6517, Train Accuracy: 0.8630, Test Accuracy: 0.7856

# %%
plot_metrics(50, train_losses, test_losses, train_accuracies, test_accuracies)

# %%
class FixedNeuralNetwork_moreData(nn.Module):
    def __init__(self, input_shape=28*28, num_classes=10, input_channels=1):
        super(self.__class__, self).__init__()
        self.model = nn.Sequential(
            nn.Flatten(),  # Конвертирует изображение в вектор
            nn.Linear(input_shape, 2048),
            nn.BatchNorm1d(2048),  # BatchNorm для стабилизации обучения
            nn.ReLU(),
            nn.Dropout(0.9),  # Dropout для уменьшения переобучения
            nn.Linear(2048, 2048),
            nn.BatchNorm1d(2048),  # BatchNorm для следующего слоя
            nn.ReLU(),
            nn.Dropout(0.7),  # Dropout
            nn.Linear(2048, 2048),
            nn.BatchNorm1d(2048),  # BatchNorm для следующего слоя
            nn.ReLU(),
            nn.Dropout(0.5),  # Dropout
            nn.Linear(2048, num_classes)  # Выходной слой с количеством классов
        )

    def forward(self, inp):
        return self.model(inp)

# %%
torchsummary.summary(FixedNeuralNetwork_moreData().to(device), (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                  [-1, 784]               0
#             Linear-2                 [-1, 2048]       1,607,680
#        BatchNorm1d-3                 [-1, 2048]           4,096
#               ReLU-4                 [-1, 2048]               0
#            Dropout-5                 [-1, 2048]               0
#             Linear-6                 [-1, 2048]       4,196,352
#        BatchNorm1d-7                 [-1, 2048]           4,096
#               ReLU-8                 [-1, 2048]               0
#            Dropout-9                 [-1, 2048]               0
#            Linear-10                 [-1, 2048]       4,196,352
#       BatchNorm1d-11                 [-1, 2048]           4,096
#              ReLU-12                 [-1, 2048]               0
#           Dropout-13                 [-1, 2048]               0
#            Linear-14                   [-1, 10]          20,490
# ================================================================
# Total params: 10,033,162
# Trainable params: 10,033,162
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.19
# Params size (MB): 38.27
# Estimated Total Size (MB): 38.47
# ----------------------------------------------------------------

# %%
model = FixedNeuralNetwork_moreData().to(device)
opt = torch.optim.Adam(model.parameters(), lr=0.001) # YOUR CODE HERE
loss_func = nn.CrossEntropyLoss()# YOUR CODE HERE

# Your experiments, come here

# %%
train_losses, test_losses, train_accuracies, test_accuracies = train_model(model, train_loader, test_loader, loss_func, opt, num_epochs=50)
# Out:
# Epoch 1/50 - Train Loss: 0.7242, Test Loss: 0.4830, Train Accuracy: 0.7369, Test Accuracy: 0.8223
# Epoch 2/50 - Train Loss: 0.5660, Test Loss: 0.4444, Train Accuracy: 0.7934, Test Accuracy: 0.8372
# Epoch 3/50 - Train Loss: 0.5215, Test Loss: 0.4136, Train Accuracy: 0.8115, Test Accuracy: 0.8477
# Epoch 4/50 - Train Loss: 0.4968, Test Loss: 0.4099, Train Accuracy: 0.8195, Test Accuracy: 0.8506
# Epoch 5/50 - Train Loss: 0.4787, Test Loss: 0.4121, Train Accuracy: 0.8267, Test Accuracy: 0.8467
# Epoch 6/50 - Train Loss: 0.4682, Test Loss: 0.3965, Train Accuracy: 0.8298, Test Accuracy: 0.8529
# Epoch 7/50 - Train Loss: 0.4578, Test Loss: 0.3954, Train Accuracy: 0.8338, Test Accuracy: 0.8526
# Epoch 8/50 - Train Loss: 0.4493, Test Loss: 0.3924, Train Accuracy: 0.8372, Test Accuracy: 0.8573
# Epoch 9/50 - Train Loss: 0.4406, Test Loss: 0.3897, Train Accuracy: 0.8384, Test Accuracy: 0.8527
# Epoch 10/50 - Train Loss: 0.4301, Test Loss: 0.3771, Train Accuracy: 0.8435, Test Accuracy: 0.8633
# Epoch 11/50 - Train Loss: 0.4227, Test Loss: 0.3687, Train Accuracy: 0.8443, Test Accuracy: 0.8637
# Epoch 12/50 - Train Loss: 0.4180, Test Loss: 0.3630, Train Accuracy: 0.8470, Test Accuracy: 0.8664
# Epoch 13/50 - Train Loss: 0.4154, Test Loss: 0.3699, Train Accuracy: 0.8482, Test Accuracy: 0.8637
# Epoch 14/50 - Train Loss: 0.4069, Test Loss: 0.3730, Train Accuracy: 0.8530, Test Accuracy: 0.8639
# Epoch 15/50 - Train Loss: 0.4039, Test Loss: 0.3672, Train Accuracy: 0.8523, Test Accuracy: 0.8667
# Epoch 16/50 - Train Loss: 0.3965, Test Loss: 0.3557, Train Accuracy: 0.8554, Test Accuracy: 0.8701
# Epoch 17/50 - Train Loss: 0.3939, Test Loss: 0.3503, Train Accuracy: 0.8579, Test Accuracy: 0.8718
# Epoch 18/50 - Train Loss: 0.3846, Test Loss: 0.3515, Train Accuracy: 0.8600, Test Accuracy: 0.8728
# Epoch 19/50 - Train Loss: 0.3819, Test Loss: 0.3490, Train Accuracy: 0.8605, Test Accuracy: 0.8743
# Epoch 20/50 - Train Loss: 0.3771, Test Loss: 0.3515, Train Accuracy: 0.8626, Test Accuracy: 0.8732
# Epoch 21/50 - Train Loss: 0.3770, Test Loss: 0.3432, Train Accuracy: 0.8624, Test Accuracy: 0.8724
# Epoch 22/50 - Train Loss: 0.3721, Test Loss: 0.3407, Train Accuracy: 0.8639, Test Accuracy: 0.8764
# Epoch 23/50 - Train Loss: 0.3690, Test Loss: 0.3384, Train Accuracy: 0.8641, Test Accuracy: 0.8773
# Epoch 24/50 - Train Loss: 0.3656, Test Loss: 0.3417, Train Accuracy: 0.8664, Test Accuracy: 0.8746
# Epoch 25/50 - Train Loss: 0.3635, Test Loss: 0.3331, Train Accuracy: 0.8662, Test Accuracy: 0.8792
# Epoch 26/50 - Train Loss: 0.3611, Test Loss: 0.3382, Train Accuracy: 0.8677, Test Accuracy: 0.8781
# Epoch 27/50 - Train Loss: 0.3586, Test Loss: 0.3349, Train Accuracy: 0.8686, Test Accuracy: 0.8792
# Epoch 28/50 - Train Loss: 0.3512, Test Loss: 0.3379, Train Accuracy: 0.8699, Test Accuracy: 0.8805
# Epoch 29/50 - Train Loss: 0.3529, Test Loss: 0.3305, Train Accuracy: 0.8692, Test Accuracy: 0.8809
# Epoch 30/50 - Train Loss: 0.3519, Test Loss: 0.3308, Train Accuracy: 0.8705, Test Accuracy: 0.8813
# Epoch 31/50 - Train Loss: 0.3508, Test Loss: 0.3257, Train Accuracy: 0.8724, Test Accuracy: 0.8794
# Epoch 32/50 - Train Loss: 0.3454, Test Loss: 0.3370, Train Accuracy: 0.8725, Test Accuracy: 0.8809
# Epoch 33/50 - Train Loss: 0.3422, Test Loss: 0.3308, Train Accuracy: 0.8738, Test Accuracy: 0.8825
# Epoch 34/50 - Train Loss: 0.3421, Test Loss: 0.3225, Train Accuracy: 0.8735, Test Accuracy: 0.8823
# Epoch 35/50 - Train Loss: 0.3408, Test Loss: 0.3242, Train Accuracy: 0.8740, Test Accuracy: 0.8830
# Epoch 36/50 - Train Loss: 0.3399, Test Loss: 0.3288, Train Accuracy: 0.8750, Test Accuracy: 0.8820
# Epoch 37/50 - Train Loss: 0.3335, Test Loss: 0.3239, Train Accuracy: 0.8788, Test Accuracy: 0.8836
# Epoch 38/50 - Train Loss: 0.3313, Test Loss: 0.3194, Train Accuracy: 0.8779, Test Accuracy: 0.8832
# Epoch 39/50 - Train Loss: 0.3310, Test Loss: 0.3322, Train Accuracy: 0.8779, Test Accuracy: 0.8818
# Epoch 40/50 - Train Loss: 0.3269, Test Loss: 0.3248, Train Accuracy: 0.8794, Test Accuracy: 0.8854
# Epoch 41/50 - Train Loss: 0.3272, Test Loss: 0.3151, Train Accuracy: 0.8787, Test Accuracy: 0.8859
# Epoch 42/50 - Train Loss: 0.3259, Test Loss: 0.3164, Train Accuracy: 0.8808, Test Accuracy: 0.8845
# Epoch 43/50 - Train Loss: 0.3189, Test Loss: 0.3165, Train Accuracy: 0.8818, Test Accuracy: 0.8862
# Epoch 44/50 - Train Loss: 0.3239, Test Loss: 0.3176, Train Accuracy: 0.8802, Test Accuracy: 0.8873
# Epoch 45/50 - Train Loss: 0.3179, Test Loss: 0.3190, Train Accuracy: 0.8821, Test Accuracy: 0.8882
# Epoch 46/50 - Train Loss: 0.3181, Test Loss: 0.3205, Train Accuracy: 0.8832, Test Accuracy: 0.8867
# Epoch 47/50 - Train Loss: 0.3185, Test Loss: 0.3161, Train Accuracy: 0.8834, Test Accuracy: 0.8864
# Epoch 48/50 - Train Loss: 0.3152, Test Loss: 0.3118, Train Accuracy: 0.8834, Test Accuracy: 0.8884
# Epoch 49/50 - Train Loss: 0.3128, Test Loss: 0.3090, Train Accuracy: 0.8847, Test Accuracy: 0.8872
# Epoch 50/50 - Train Loss: 0.3114, Test Loss: 0.3140, Train Accuracy: 0.8859, Test Accuracy: 0.8875

# %%
plot_metrics(50, train_losses, test_losses, train_accuracies, test_accuracies)

# %% [markdown]
# ### Conclusions:
# _Write down small report with your conclusions and your ideas._

# %% [markdown]
# Заключение:
# В ходе выполнения лабораторной работы, целью которой было преодоление переобучения модели на датасете Fashion-MNIST, было сделано следующее:
#
# Была создана базовая модель с несколькими слоями nn.Linear и функциями активации для достижения целевой точности ≥0.885.
#
# Модель с переобучением (Task 2):
#
# Для того чтобы показать явное переобучение, модель была значительно увеличена путем добавления большего количества слоев и нейронов, а также уменьшения размера обучающего набора данных. Это привело к улучшению метрик качества на обучающем наборе данных, но к ухудшению результатов на тестовом наборе — очевидное проявление переобучения.
#
# Уменьшение переобучения с помощью регуляризации (Task 3):
#
# Для борьбы с переобучением были использовали две основные техники регуляризации:
# Dropout - случайное исключение части нейронов на каждой итерации для предотвращения запоминания модели.
# BatchNormalization - нормализация активаций на каждом слое, чтобы ускорить обучение и стабилизировать градиенты.
# Эти методы позволили значительно улучшить стабильность модели и уменьшить переобучение. Точность на тестовом наборе данных улучшилась, и модель стала менее склонна к запоминанию обучающих данных.
#
# Тем не менее, точность на обучающих данных все еще превышала таковую на тестовых. Увеличение размера обучающего набора данных позволила изменить ситуацию - точность на тестовых данных сошлась с таковой на обучающих.
